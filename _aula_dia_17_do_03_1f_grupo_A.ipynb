# %% [markdown]
# <a href="https://colab.research.google.com/github/arthuralvesja25-ai/PA-1F-grupo-A/blob/main/_aula_dia_17_do_03_1f_grupo_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# operação aritimetica
# fazer um programa que calcula operações com 02 numero

# entrada

a = int(input("digite um numero:"))
b = int(input("digite um numero:"))

# processamento

soma = a + b
subtracao = a - b
multiplicacao = a * b
divisao = a / b
div_int = a // b
resto = a % b
potencia = a ** b

# saida

print("")
print("----------------------OPERADORES ARITIMETICOS----------------------")
print("")
print("---------------------------------SOMA-------------------------------")
print("")
print (f"o resultado da SOMA de {a} MAIS {b} é igual a: {soma} ")
print("")
print("----------------------OPERADORES ARITIMETICOS----------------------")
print("")
print("------------------------------SUBTRAÇÃO-----------------------------")
print("")
print (f"o resultado da SUBTRAÇÃO de {a} MENOS {b} é igual a: {subtracao} ")
print("")
print("----------------------OPERADORES ARITIMETICOS----------------------")
print("")
print("------------------------------MUTIPLICAÇÃO-----------------------------")
print("")
print (f"o resultado da MULTIPLICAÇÃO de {a} MULTIPLICADO por {b} é igual a: {multiplicacao} ")
print("")
print("----------------------OPERADORES ARITIMETICOS----------------------")
print("")
print("---------------------------------DIVISÃO-------------------------------")
print("")
print (f"o resultado da DIVISÃO de {a} DIVIDIDO por {b} é igual a: {divisao} ")
print("")
print("---------------------------------DIVISÃO INTEIRA-------------------------------")
print("")
print (f"o resultado da DIVISÃO INTEIRA de {a} DIVIDIDO por {b} é igual a: {div_int} ")
print("")
print("---------------------------------RESTO DA DIVISÃO-------------------------------")
print("")
print (f"o resto da DIVISÃO de {a} DIVIDIDO por {b} é igual a: {resto} ")
print("")
print("--------------------------------POTENCIAÇÃO-------------------------------")
print("")
print (f"o resultado da POTENCIA de {a} ELEVADO {b} é igual a: {potencia} ")
print("")
# Out:
# digite um numero:18
# digite um numero:20
#
# ----------------------OPERADORES ARITIMETICOS----------------------
#
# ---------------------------------SOMA-------------------------------
#
# o resultado da SOMA de 18 MAIS 20 é igual a: 38
#
# ----------------------OPERADORES ARITIMETICOS----------------------
#
# ------------------------------SUBTRAÇÃO-----------------------------
#
# o resultado da SUBTRAÇÃO de 18 MENOS 20 é igual a: -2
#
# ----------------------OPERADORES ARITIMETICOS----------------------
#
# ------------------------------MUTIPLICAÇÃO-----------------------------
#
# o resultado da MULTIPLICAÇÃO de 18 MULTIPLICADO por 20 é igual a: 360
#
# ----------------------OPERADORES ARITIMETICOS----------------------
#
# ---------------------------------DIVISÃO-------------------------------
#
# o resultado da DIVISÃO de 18 DIVIDIDO por 20 é igual a: 0.9
#
# ---------------------------------DIVISÃO INTEIRA-------------------------------
#
# ...

# %%
# operadores relacionais

# entrada

a = int(input("digite um numero: "))
b = int(input("digite um numero: "))

# processamento

# comparação
igual = a == b

# saida
print(igual)
# Out:
# digite um numero: 3
# digite um numero: 4
# False

# %%
# Operadores Relacionais

# entrada

a = int(input("digite um numero: "))
b = int(input("digite um numero: "))

# processamento

# comparação

diferente = a != b

# saida
print(diferente)
# Out:
# digite um numero: 5
# digite um numero: 7
# True

# %%
# operadores relacionais

# entrada

a = int(input("digite um numero: "))
b = int(input("digite um numero: "))

# processamento

# comparação

maior = a > b
menor = a < b
maiorigual = a >= b
menorigual = a <= b

print(maior)
print(menor)
print(maiorigual)
print(menorigual)
# Out:
# digite um numero: 6
# digite um numero: 7
# False
# True
# False
# True

# %%
# fazer um programa que converta a temperatura
# F= (C X 9/5 ) + 32

C = float(input("digite uma temperatura em celsius :"))

Resultado = (C * 9/5 ) + 32

print(f"{C} graus celsius equivale a {Resultado} graus fahrenheit")
# Out:
# digite uma temperatura em celsius :67
# 67.0 graus celsius equivale a 152.6 graus fahrenheit

# %%
# fazer um programa que converte km em metros

km = float(input("digite um numero em km: "))

Resultado + km * 1000

print(f"{km} kilometros equivale á {Resultado} metros")
# Out:
# digite um numero em km: 3
# 3.0 kilometros equivale á 152.6 metros

# %%
# fazer um programa que convertw horas em minutos

H = float(input("digite um numero em horas: "))

Resultado = H * 60

print(f"{H} horas equivale {Resultado} minutos")
# Out:
# digite um numero em horas: 5
# 5.0 horas equivale 300.0 minutos
